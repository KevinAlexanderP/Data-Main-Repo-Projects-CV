# %% [markdown]
# About
#
# This dataset contains latest Covid-19 India state-wise data as on August 18, 2021. This dataset can be used to analyze covid condition in India.
# This dataset is great for Exploratory Data Analysis
#
# Attribute Information
#
# State/UTs - Names of Indian States and Union Territories.
# Total Cases - Total number of confirmed cases
# Active - Total number of active cases
# Discharged - Total number of discharged cases
# Deaths - Total number of deaths
# Active Ratio (%) - Ratio of number of active cases to total cases
# Discharge Ratio (%) - Ratio of number of discharged cases to total cases
# Death Ratio (%) - Ratio of number of deaths to total cases
# Source
#
# Link : https://www.mygov.in/covid-19
#
# If you find this dataset useful, please consider upvoting ❤️
# EDA by AlexanderPerez

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Importing the Data from our Csv file **

# %%
data = pd.read_csv('/content/Latest Covid-19 India Status.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
data['Total Cases']
# Out:
# 0        7549
# 1     1995669
# 2       51655
# 3      581398
# 4      725518
# 5       62035
# 6     1003870
# 7       10657
# 8     1437156
# 9      172683
# 10     825213
# 11     770245
# 12     210719
# 13     323582
# 14     347635
# 15    2931827
# 16    3724030
# 17      20466
# 18      10295
# 19     792054
# 20    6401213
# 21     108948
# 22      72412
# 23      49950
# 24      29274
# 25     996153
# 26     122391
# 27     600008
# 28     953960
# 29      28830
# 30    2592436
# 31     653202
# 32      81584
# 33    1708991
# 34     342637
# 35    1539612
# Name: Total Cases, dtype: int64

# %%
# Statistical Analisis
data.describe()
# Out:
#         Total Cases         Active  ...  Discharge Ratio (%)  Death Ratio (%)
# count  3.600000e+01      36.000000  ...            36.000000        36.000000
# mean   8.968294e+05   10205.972222  ...            97.052222         1.265000
# std    1.303563e+06   30660.005408  ...             3.239175         0.564464
# min    7.549000e+03       1.000000  ...            81.440000         0.040000
# 25%    6.981775e+04     213.750000  ...            97.150000         0.947500
# 50%    4.645165e+05    1062.500000  ...            98.200000         1.320000
# 75%    9.980822e+05    7369.500000  ...            98.597500         1.607500
# max    6.401213e+06  175695.000000  ...            99.920000         2.720000
#
# [8 rows x 7 columns]

# %% [markdown]
# **Setting up Our Statistics to find , good insights**

# %%
sns.set_style('dark')
plt.figure(figsize = (10, 12))
plt.title('Total cases for each state in India')
sns.barplot(data = data, y = 'State/UTs', x = 'Total Cases')
plt.xlabel('Total Cases (million)')
# Out:
# Text(0.5, 0, 'Total Cases (million)')

# %%
plt.figure(figsize = (13, 8))
plt.title("Active case vs Total Case trend", fontsize = 16)
sns.regplot(data = data, x = 'Total Cases', y = 'Active', color = 'red')
plt.xlabel('Total Cases (millions)')
# Out:
# Text(0.5, 0, 'Total Cases (millions)')

# %% [markdown]
# We can see from the data that Maharashtra has the highest total number of cases while Andaman and Nicobar has the lowest total number of cases in India

# %%
sns.lmplot(data = data, x = 'Total Cases', y = 'Active', hue = 'State/UTs')
plt.title('Active case vs Total case for each states', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Active case vs Total case for each states')

# %% [markdown]
# Number of recoveries VS number of total case

# %%
plt.figure(figsize = (13, 8))
plt.title("Discharged vs Total Case trend", fontsize = 16)
sns.regplot(data = data, x = 'Total Cases', y = 'Discharged', color = 'green')
plt.xlabel('Total Cases (millions)')
# Out:
# Text(0.5, 0, 'Total Cases (millions)')

# %%
high_total_case = data[data['Total Cases'] == max(data['Total Cases'])]
high_total_case
# Out:
#       State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 20  Maharashtra      6401213  ...                96.87             2.11
#
# [1 rows x 8 columns]

# %%
low_total_case = data[data['Total Cases'] == min(data['Total Cases'])]
low_total_case
# Out:
#              State/UTs  Total Cases  ...  Discharge Ratio (%)  Death Ratio (%)
# 0  Andaman and Nicobar         7549  ...                98.28             1.71
#
# [1 rows x 8 columns]

# %% [markdown]
# 10 States with most cases in India

# %% [markdown]
# 10 States with minimum active  Cases

# %%
df1 = data.sort_values(by='Active', ascending=False).head(10)
states = df1['State/UTs']
cases = df1['Active']
plt.barh(states,cases, color = 'red')
plt.xlabel('Active Cases')
plt.ylabel('State')
plt.title('State with  more Active Cases in India')
plt.show()

# %% [markdown]
# Top 10 states with max number of covid death cases

# %%
df2 = data.sort_values(by='Active').head(10)
states = df2['State/UTs']
cases = df2['Active']
plt.barh(states,cases, color = 'green')
plt.xlabel('Active Cases')
plt.ylabel('State')
plt.title('State with minimum Active Cases in India')
plt.show()

# %%
df2 = data.sort_values(by='Death Ratio (%)',ascending=False)
df2
# Out:
#                                    State/UTs  ...  Death Ratio (%)
# 27                                    Punjab  ...             2.72
# 34                               Uttarakhand  ...             2.15
# 20                               Maharashtra  ...             2.11
# 24                                  Nagaland  ...             2.07
# 9                                        Goa  ...             1.84
# 8                                      Delhi  ...             1.74
# 0                        Andaman and Nicobar  ...             1.71
# 22                                 Meghalaya  ...             1.71
# 12                          Himachal Pradesh  ...             1.69
# 21                                   Manipur  ...             1.58
# 14                                 Jharkhand  ...             1.48
# 26                                Puducherry  ...             1.47
# 13                         Jammu and Kashmir  ...             1.36
# 6                               Chhattisgarh  ...             1.35
# 30                                Tamil Nadu  ...             1.33
# 4                                      Bihar  ...             1.33
# 19                            Madhya Pradesh  ...             1.33
# 33                             Uttar Pradesh  ...             1.33
# 5                                 Chandigarh  ...             1.31
# 15                                 Karnataka  ...             1.26
# 29                                    Sikkim  ...             1.26
# 11                                   Haryana  ...             1.25
# 10                                   Gujarat  ...             1.22
# 35                               West Bengal  ...             1.19
# 17                                    Ladakh  ...             1.01
# 32                                   Tripura  ...             0.96
# 3                                      Assam  ...             0.95
# 28                                 Rajasthan  ...             0.94
# 25                                    Odisha  ...             0.70
# 1                             Andhra Pradesh  ...             0.69
# 31                                 Telengana  ...             0.59
# 16                                    Kerala  ...             0.51
# 18                               Lakshadweep  ...             0.50
# 2                          Arunachal Pradesh  ...             0.49
# 23                                   Mizoram  ...             0.37
# 7   Dadra and Nagar Haveli and Daman and Diu  ...             0.04
#
# [36 rows x 8 columns]

# %%
px.line(data, x='State/UTs', y='Death Ratio (%)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a3a02c7d-b0cc-4f81-8547-e5b150fc1c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a3a02c7d-b0cc-4f81-8547-e5b150fc1c1d")) {
#                     Plotly.newPlot(
#                         'a3a02c7d-b0cc-4f81-8547-e5b150fc1c1d',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Death Ratio (%)=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "xaxis": "x", "y": [1.71, 0.69, 0.49, 0.95, 1.33, 1.31, 1.35, 0.04, 1.74, 1.84, 1.22, 1.25, 1.69, 1.36, 1.48, 1.26, 0.51, 1.01, 0.5, 1.33, 2.11, 1.58, 1.71, 0.37, 2.07, 0.7, 1.47, 2.72, 0.94, 1.26, 1.33, 0.59, 0.96, 1.33, 2.15, 1.19], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
px.scatter_3d(data, x='State/UTs', z='Total Cases', y='Active', color = 'Active', width=700, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9ad4912b-ddd9-4b10-94e8-0c8b471c39c9" class="plotly-graph-div" style="height:600px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9ad4912b-ddd9-4b10-94e8-0c8b471c39c9")) {
#                     Plotly.newPlot(
#                         '9ad4912b-ddd9-4b10-94e8-0c8b471c39c9',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Active=%{marker.color}<br>Total Cases=%{z}", "legendgroup": "", "marker": {"color": [1, 16341, 1763, 8772, 204, 42, 1037, 4, 471, 884, 179, 660, 2705, 1158, 217, 21507, 175695, 81, 34, 95, 64790, 5721, 3591, 9084, 1088, 8661, 856, 543, 163, 1982, 20225, 6939, 1436, 420, 330, 9736], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "y": [1, 16341, 1763, 8772, 204, 42, 1037, 4, 471, 884, 179, 660, 2705, 1158, 217, 21507, 175695, 81, 34, 95, 64790, 5721, 3591, 9084, 1088, 8661, 856, 543, 163, 1982, 20225, 6939, 1436, 420, 330, 9736], "z": [7549, 1995669, 51655, 581398, 725518, 62035, 1003870, 10657, 1437156, 172683, 825213, 770245, 210719, 323582, 347635, 2931827, 3724030, 20466, 10295, 792054, 6401213, 108948, 72412, 49950, 29274, 996153, 122391, 600008, 953960, 28830, 2592436, 653202, 81584, 1708991, 342637, 1539612]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Active"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "State/UTs"}}, "yaxis": {"title": {"text": "Active"}}, "zaxis": {"title": {"text": "Total Cases"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": ...

# %% [markdown]
# n the above 3D plot Maharastra may have the maximum number of covid cases but Kerala has the maximum number of active cases.

# %% [markdown]
# Punjab is the place with the most Deaths along the numbers

# %%
px.bar_polar(data, r="Death Ratio (%)", theta="State/UTs", color="Deaths",
              title="Deaths vs Death Ratio Visualisation"
            )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d7a4775-972a-4af5-aa91-8d168cbcd13b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d7a4775-972a-4af5-aa91-8d168cbcd13b")) {
#                     Plotly.newPlot(
#                         '6d7a4775-972a-4af5-aa91-8d168cbcd13b',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=129<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=129", "marker": {"color": "#636efa"}, "name": "Deaths=129", "r": [1.71], "showlegend": true, "subplot": "polar", "theta": ["Andaman and Nicobar"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=13671<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=13671", "marker": {"color": "#EF553B"}, "name": "Deaths=13671", "r": [0.69], "showlegend": true, "subplot": "polar", "theta": ["Andhra Pradesh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=252<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=252", "marker": {"color": "#00cc96"}, "name": "Deaths=252", "r": [0.49], "showlegend": true, "subplot": "polar", "theta": ["Arunachal Pradesh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=5513<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=5513", "marker": {"color": "#ab63fa"}, "name": "Deaths=5513", "r": [0.95], "showlegend": true, "subplot": "polar", "theta": ["Assam"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=9649<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=9649", "marker": {"color": "#FFA15A"}, "name": "Deaths=9649", "r": [1.33], "showlegend": true, "subplot": "polar", "theta": ["Bihar"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=811<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=811", "marker": {"color": "#19d3f3"}, "name": "Deaths=811", "r": [1.31], "showlegend": true, "subplot": "polar", "theta": ["Chandigarh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=13549<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=13549", "marker": {"color": "#FF6692"}, "name": "Deaths=13549", "r": [1.35], "showlegend": true, "subplot": "polar", "theta": ["Chhattisgarh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=4<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=4", "marker": {"color": "#B6E880"}, "name": "Deaths=4", "r": [0.04], "showlegend": true, "subplot": "polar", "theta": ["Dadra and Nagar Haveli and Daman and Diu"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=25073<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=25073", "marker": {"color": "#FF97FF"}, "name": "Deaths=25073", "r": [1.74], "showlegend": true, "subplot": "polar", "theta": ["Delhi"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=3177<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=3177", "marker": {"color": "#FECB52"}, "name": "Deaths=3177", "r": [1.84], "showlegend": true, "subplot": "polar", "theta": ["Goa"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=10078<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=10078", "marker": {"color": "#636efa"}, "name": "Deaths=10078", "r": [1.22], "showlegend": true, "subplot": "polar", "theta": ["Gujarat"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=9661<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=9661", "marker": {"color": "#EF553B"}, "name": "Deaths=9661", "r": [1.25], "showlegend": true, "subplot": "polar", "theta": ["Haryana"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=3557<br>Death Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Deaths=3557", "marker": {"color": "#00cc96"}, "name": "Deaths=3557", "r": [1.69], "showlegend": true, "subplot": "polar", "theta": ["Himachal Pradesh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Deaths=4399<br>Death Ratio (%)=%{r}<br>State/UTs=%{ ...

# %% [markdown]
# Discharge ratio vs Total Dischaege

# %%
px.bar_polar(data, r="Discharge Ratio (%)", theta="State/UTs", color="Discharged",
                   title="Discharged vs Discharge Ratio Visualization"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b0fa6977-8711-44fb-bb34-3b1d45b5fc59" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0fa6977-8711-44fb-bb34-3b1d45b5fc59")) {
#                     Plotly.newPlot(
#                         'b0fa6977-8711-44fb-bb34-3b1d45b5fc59',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=7419<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=7419", "marker": {"color": "#636efa"}, "name": "Discharged=7419", "r": [98.28], "showlegend": true, "subplot": "polar", "theta": ["Andaman and Nicobar"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=1965657<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=1965657", "marker": {"color": "#EF553B"}, "name": "Discharged=1965657", "r": [98.5], "showlegend": true, "subplot": "polar", "theta": ["Andhra Pradesh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=49640<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=49640", "marker": {"color": "#00cc96"}, "name": "Discharged=49640", "r": [96.1], "showlegend": true, "subplot": "polar", "theta": ["Arunachal Pradesh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=567113<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=567113", "marker": {"color": "#ab63fa"}, "name": "Discharged=567113", "r": [97.54], "showlegend": true, "subplot": "polar", "theta": ["Assam"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=715665<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=715665", "marker": {"color": "#FFA15A"}, "name": "Discharged=715665", "r": [98.64], "showlegend": true, "subplot": "polar", "theta": ["Bihar"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=61182<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=61182", "marker": {"color": "#19d3f3"}, "name": "Discharged=61182", "r": [98.62], "showlegend": true, "subplot": "polar", "theta": ["Chandigarh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=989284<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=989284", "marker": {"color": "#FF6692"}, "name": "Discharged=989284", "r": [98.55], "showlegend": true, "subplot": "polar", "theta": ["Chhattisgarh"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=10649<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=10649", "marker": {"color": "#B6E880"}, "name": "Discharged=10649", "r": [99.92], "showlegend": true, "subplot": "polar", "theta": ["Dadra and Nagar Haveli and Daman and Diu"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=1411612<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=1411612", "marker": {"color": "#FF97FF"}, "name": "Discharged=1411612", "r": [98.22], "showlegend": true, "subplot": "polar", "theta": ["Delhi"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=168622<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=168622", "marker": {"color": "#FECB52"}, "name": "Discharged=168622", "r": [97.65], "showlegend": true, "subplot": "polar", "theta": ["Goa"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=814956<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=814956", "marker": {"color": "#636efa"}, "name": "Discharged=814956", "r": [98.76], "showlegend": true, "subplot": "polar", "theta": ["Gujarat"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=759924<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup": "Discharged=759924", "marker": {"color": "#EF553B"}, "name": "Discharged=759924", "r": [98.66], "showlegend": true, "subplot": "polar", "theta": ["Haryana"], "type": "barpolar"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Discharged=204457<br>Discharge Ratio (%)=%{r}<br>State/UTs=%{theta}", "legendgroup ...

# %%
barFig = px.scatter(data, x="State/UTs", y="Total Cases", color="Discharge Ratio (%)")
# Rotate labels 45 degrees
barFig.update_layout(xaxis_tickangle=-90)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f88ddd5-97e9-49fe-9377-f28cf6781343" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f88ddd5-97e9-49fe-9377-f28cf6781343")) {
#                     Plotly.newPlot(
#                         '3f88ddd5-97e9-49fe-9377-f28cf6781343',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Total Cases=%{y}<br>Discharge Ratio (%)=%{marker.color}", "legendgroup": "", "marker": {"color": [98.28, 98.5, 96.1, 97.54, 98.64, 98.62, 98.55, 99.92, 98.22, 97.65, 98.76, 98.66, 97.03, 98.28, 98.46, 98.0, 94.78, 98.59, 99.17, 98.66, 96.87, 93.17, 93.33, 81.44, 94.21, 98.43, 97.83, 97.19, 99.04, 91.87, 97.89, 98.35, 97.28, 98.64, 97.75, 98.18], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "xaxis": "x", "y": [7549, 1995669, 51655, 581398, 725518, 62035, 1003870, 10657, 1437156, 172683, 825213, 770245, 210719, 323582, 347635, 2931827, 3724030, 20466, 10295, 792054, 6401213, 108948, 72412, 49950, 29274, 996153, 122391, 600008, 953960, 28830, 2592436, 653202, 81584, 1708991, 342637, 1539612], "yaxis": "y"}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Discharge Ratio (%)"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl":  ...

# %% [markdown]
# Visualizing each states on the basis of Active cases, Discharge Ratio and Total Cases

# %%
px.scatter_3d(data, x='State/UTs', z='Active', y='Discharge Ratio (%)', color ='Total Cases', width=700, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67f0fee6-9106-402c-9c15-98d623fd49ca" class="plotly-graph-div" style="height:600px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67f0fee6-9106-402c-9c15-98d623fd49ca")) {
#                     Plotly.newPlot(
#                         '67f0fee6-9106-402c-9c15-98d623fd49ca',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Discharge Ratio (%)=%{y}<br>Active=%{z}<br>Total Cases=%{marker.color}", "legendgroup": "", "marker": {"color": [7549, 1995669, 51655, 581398, 725518, 62035, 1003870, 10657, 1437156, 172683, 825213, 770245, 210719, 323582, 347635, 2931827, 3724030, 20466, 10295, 792054, 6401213, 108948, 72412, 49950, 29274, 996153, 122391, 600008, 953960, 28830, 2592436, 653202, 81584, 1708991, 342637, 1539612], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "y": [98.28, 98.5, 96.1, 97.54, 98.64, 98.62, 98.55, 99.92, 98.22, 97.65, 98.76, 98.66, 97.03, 98.28, 98.46, 98.0, 94.78, 98.59, 99.17, 98.66, 96.87, 93.17, 93.33, 81.44, 94.21, 98.43, 97.83, 97.19, 99.04, 91.87, 97.89, 98.35, 97.28, 98.64, 97.75, 98.18], "z": [1, 16341, 1763, 8772, 204, 42, 1037, 4, 471, 884, 179, 660, 2705, 1158, 217, 21507, 175695, 81, 34, 95, 64790, 5721, 3591, 9084, 1088, 8661, 856, 543, 163, 1982, 20225, 6939, 1436, 420, 330, 9736]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Total Cases"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "State/UTs"}}, "yaxis": {"title": {"text": "Discharge Ratio (%)"}}, "zaxis": {"title": {"text": "Active"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet" ...

# %%
px.scatter(data, x="State/UTs", y="Death Ratio (%)", color="Discharge Ratio (%)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4629093a-77b3-409b-a953-d4b703df821e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4629093a-77b3-409b-a953-d4b703df821e")) {
#                     Plotly.newPlot(
#                         '4629093a-77b3-409b-a953-d4b703df821e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Death Ratio (%)=%{y}<br>Discharge Ratio (%)=%{marker.color}", "legendgroup": "", "marker": {"color": [98.28, 98.5, 96.1, 97.54, 98.64, 98.62, 98.55, 99.92, 98.22, 97.65, 98.76, 98.66, 97.03, 98.28, 98.46, 98.0, 94.78, 98.59, 99.17, 98.66, 96.87, 93.17, 93.33, 81.44, 94.21, 98.43, 97.83, 97.19, 99.04, 91.87, 97.89, 98.35, 97.28, 98.64, 97.75, 98.18], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "xaxis": "x", "y": [1.71, 0.69, 0.49, 0.95, 1.33, 1.31, 1.35, 0.04, 1.74, 1.84, 1.22, 1.25, 1.69, 1.36, 1.48, 1.26, 0.51, 1.01, 0.5, 1.33, 2.11, 1.58, 1.71, 0.37, 2.07, 0.7, 1.47, 2.72, 0.94, 1.26, 1.33, 0.59, 0.96, 1.33, 2.15, 1.19], "yaxis": "y"}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Discharge Ratio (%)"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl":  ...

# %% [markdown]
# Active VS Deaths

# %%
barFig = px.scatter(data, x="State/UTs", y="Active", color="Deaths")
# Rotate labels 45 degrees
barFig.update_layout(xaxis_tickangle=-90)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44b40daf-5ba6-4783-8665-603a8c2172cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44b40daf-5ba6-4783-8665-603a8c2172cc")) {
#                     Plotly.newPlot(
#                         '44b40daf-5ba6-4783-8665-603a8c2172cc',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "State/UTs=%{x}<br>Active=%{y}<br>Deaths=%{marker.color}", "legendgroup": "", "marker": {"color": [129, 13671, 252, 5513, 9649, 811, 13549, 4, 25073, 3177, 10078, 9661, 3557, 4399, 5132, 37039, 18870, 207, 51, 10515, 135255, 1722, 1240, 185, 607, 7021, 1805, 16345, 8954, 363, 34579, 3847, 782, 22786, 7373, 18318], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["Andaman and Nicobar", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu and Kashmir", "Jharkhand", "Karnataka", "Kerala", "Ladakh", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telengana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal"], "xaxis": "x", "y": [1, 16341, 1763, 8772, 204, 42, 1037, 4, 471, 884, 179, 660, 2705, 1158, 217, 21507, 175695, 81, 34, 95, 64790, 5721, 3591, 9084, 1088, 8661, 856, 543, 163, 1982, 20225, 6939, 1436, 420, 330, 9736], "yaxis": "y"}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Deaths"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": { ...

# %%
#High Correlation between Total Cases and recovery(Discharged); Lowest Correlation between Active cases and Deaths
sns.heatmap(data.corr())

# %% [markdown]
# Conclusions :
#
# Active Ratio is codependant to Discharge Ratio
# - Place with more Deaths is Punjab
# - Place with less Deaths is Dadra and Nagar Haveli and Daman and Diu
# - In the above 3D plot Maharastra may have the maximum number of covid cases but Kerala has the maximum number of active cases.
# - Total cases has a relation with the death cases.
# - Jharkhand is the place with less active cases
